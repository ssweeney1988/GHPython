# %%
#import rhinoscriptsyntax as rs


listtest = [6500,6250,6250,6000,6000,5750]
extrusions_list = []
surfaces_list = []
count = 0


for i in listtest:
    count = count + 1
  
    # the i is the geometry
    # this is where we need to evaluate the line (i) coming in AT ANY POINT and find the z point 
    #rs.evaluatecurve(i)
    current_height = i
    
    # want to look at both the points and the line
    
    # the first step so dont do a comparision yet
    if count == 1:
        previous_height = current_height
        previous_line = i
        print ('first step at height ' + str(current_height))
    else:
        # same height levels
        if current_height == previous_height:
            
            print ('surface made')
            # we need to do rs.evaluatecurve and draw the two lines
            
            # this two lines are i and previous line
            
            #rs. addline(input the two curve types)
            #joined_curve = rs.JoinCurves(objs)
            #surface = rs.AddPlanarSrf(joined_curve)
            #join the previous line with i, evaluate the end points and draw lines between them on both ends and join
            # then make a surface
            # append it to a surfaces list
            # surfaces_list.append[surface]
            
            
            previous_height = current_height
            previous_line = i
            # this is then where we make our joined polyline
            
        # if the heights are different 
        else: 
            difference = previous_height - current_height
            print (difference)
            #extrusion = rs.ExtrudeCurveStraight(i, (0,0,difference), (0, 0, difference) )
            
            #we want to extrude the current i geometry up this height
            # extrude i in the y direction by the difference height
            # extrusions_list.append[extrusion]
            
            previous_height = current_height
            previous_line = i
            
            # make sure the last datapoint is a flat
            if count == len(listtest):
                print ('last data point at height ' + str(current_height))
                
            

            
           
            
            # this is where we want to extrude the difference 
        #test_difference
